# %%
# 01 문제정의
# 02 데이터가져오기
# 03 EDA
# 04 데이터전처리
# 05 검증데이터 분할 및 학습
# 06 테스트 및 검증지표 확인
# 07 Model 내보내기 , 테스트파일 내보내기

# %%
#-------------------------------------------------
# 01 문제정의
#-------------------------------------------------

# %%
# Out:
# train: (6818, 12) | test: (1705, 11)

# %%
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              NCR06       12.500          Low Fat         0.006760
# 1              FDW11       12.600          Low Fat         0.048741
# 2              FDH32       12.800          Low Fat         0.075997
# 3              FDL52        6.635          Regular         0.046351
# 4              FDO09       13.500          Regular         0.125170
# ...              ...          ...              ...              ...
# 6813           NCC54       17.750          Low Fat         0.097863
# 6814           NCF19       13.000          Low Fat         0.035252
# 6815           FDU11        4.785          Low Fat         0.092576
# 6816           FDK14        6.980          Low Fat         0.041189
# 6817           NCD31          NaN          Low Fat         0.015360
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                 Household   42.8112            OUT013
# 1                    Breads   60.4194            OUT013
# 2     Fruits and Vegetables   97.1410            OUT013
# 3              Frozen Foods   37.4506            OUT017
# 4               Snack Foods  261.4910            OUT013
# ...                     ...       ...               ...
# 6813     Health and Hygiene  239.3196            OUT049
# 6814              Household   48.0034            OUT018
# 6815                 Breads  121.0098            OUT035
# 6816                 Canned   82.8934            OUT045
# 6817              Household  163.7526            OUT027
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1987        High               Tier 3
# 1                          1987        High               Tier 3
# 2                          1987        High               Tier 3
# 3                          2007         NaN               Tier 2
# 4                          1987        High               Tier 3
# ...                         ...         ...                  ...
# 6813                       1999      Medium               Tier 1
# 6814                       2009      Medium               Tier 3
# 6815                       2004       Small               Tier 2
# 6816                       2002         NaN               Tier 2
# 6817                       1985      Medium               Tier 3
#
#             Outlet_Type  Item_Outlet_Sales
# 0     Supermarket Type1           639.1680
# 1     Supermarket Type1           990.7104
# 2     Supermarket Type1          2799.6890
# 3     Supermarket Type1          1176.4686
# 4     Supermarket Type1          3418.8830
# ...                 ...                ...
# 6813  Supermarket Type1          3615.2940
# 6814  Supermarket Type2           923.4646
# 6815  Supermarket Type1          2530.7058
# 6816  Supermarket Type1           818.9340
# 6817  Supermarket Type3          1973.4312
#
# [6818 rows x 12 columns]

# %%
#-------------------------------------------------
# 02 데이터가져오기
#-------------------------------------------------

# %%
import pandas as pd
train = pd.read_csv('train.csv', low_memory=False) # 학습용 데이터 읽기 (low_memory=False: 타입 혼합 경고 방지)
test  = pd.read_csv('test.csv', low_memory=False)  # 학습용 데이터 읽기 (low_memory=False: 타입 혼합 경고 방지)
print('train:', train.shape, '| test:', test.shape)
# Out:
# train: (6818, 12) | test: (1705, 11)

# %%
#-------------------------------------------------
# 03 EDA
#-------------------------------------------------

# %%
train.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           NCR06       12.500          Low Fat         0.006760
# 1           FDW11       12.600          Low Fat         0.048741
# 2           FDH32       12.800          Low Fat         0.075997
# 3           FDL52        6.635          Regular         0.046351
# 4           FDO09       13.500          Regular         0.125170
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0              Household   42.8112            OUT013
# 1                 Breads   60.4194            OUT013
# 2  Fruits and Vegetables   97.1410            OUT013
# 3           Frozen Foods   37.4506            OUT017
# 4            Snack Foods  261.4910            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1987        High               Tier 3
# 1                       1987        High               Tier 3
# 2                       1987        High               Tier 3
# 3                       2007         NaN               Tier 2
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1           639.1680
# 1  Supermarket Type1           990.7104
# 2  Supermarket Type1          2799.6890
# 3  Supermarket Type1          1176.4686
# 4  Supermarket Type1          3418.8830

# %%
test.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDO38       17.250          Low Fat         0.073251
# 1           FDO32        6.360          Low Fat         0.120544
# 2           FDT14       10.695          Regular         0.128247
# 3           FDG50        7.405          Low Fat         0.015296
# 4           FDR11       10.500          Regular         0.142760
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                 Canned   76.4986            OUT017
# 1  Fruits and Vegetables   45.8060            OUT046
# 2                  Dairy  121.8440            OUT018
# 3                 Canned   89.7146            OUT049
# 4                 Breads  159.3578            OUT049
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       2007         NaN               Tier 2
# 1                       1997       Small               Tier 1
# 2                       2009      Medium               Tier 3
# 3                       1999      Medium               Tier 1
# 4                       1999      Medium               Tier 1
#
#          Outlet_Type
# 0  Supermarket Type1
# 1  Supermarket Type1
# 2  Supermarket Type2
# 3  Supermarket Type1
# 4  Supermarket Type1

# %%
# train.describe()
train.describe(include="O")
# Out:
#        Item_Identifier Item_Fat_Content    Item_Type Outlet_Identifier  \
# count             6818             6818         6818              6818
# unique            1554                5           16                10
# top              FDO19          Low Fat  Snack Foods            OUT046
# freq                 9             4092          963               763
#
#        Outlet_Size Outlet_Location_Type        Outlet_Type
# count         4878                 6818               6818
# unique           3                    3                  4
# top         Medium               Tier 3  Supermarket Type1
# freq          2228                 2664               4474

# %%
# test.describe()
test.describe(include="O")
# Out:
#        Item_Identifier Item_Fat_Content              Item_Type  \
# count             1705             1705                   1705
# unique            1077                5                     16
# top              DRD15          Low Fat  Fruits and Vegetables
# freq                 4              997                    272
#
#        Outlet_Identifier Outlet_Size Outlet_Location_Type        Outlet_Type
# count               1705        1235                 1705               1705
# unique                10           3                    3                  4
# top               OUT013      Medium               Tier 3  Supermarket Type1
# freq                 207         565                  686               1103

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6818 entries, 0 to 6817
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            6818 non-null   object
#  1   Item_Weight                5656 non-null   float64
#  2   Item_Fat_Content           6818 non-null   object
#  3   Item_Visibility            6818 non-null   float64
#  4   Item_Type                  6818 non-null   object
#  5   Item_MRP                   6818 non-null   float64
#  6   Outlet_Identifier          6818 non-null   object
#  7   Outlet_Establishment_Year  6818 non-null   int64
#  8   Outlet_Size                4878 non-null   object
#  9   Outlet_Location_Type       6818 non-null   object
#  10  Outlet_Type                6818 non-null   object
#  11  Item_Outlet_Sales          6818 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 639.3+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1705 entries, 0 to 1704
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            1705 non-null   object
#  1   Item_Weight                1404 non-null   float64
#  2   Item_Fat_Content           1705 non-null   object
#  3   Item_Visibility            1705 non-null   float64
#  4   Item_Type                  1705 non-null   object
#  5   Item_MRP                   1705 non-null   float64
#  6   Outlet_Identifier          1705 non-null   object
#  7   Outlet_Establishment_Year  1705 non-null   int64
#  8   Outlet_Size                1235 non-null   object
#  9   Outlet_Location_Type       1705 non-null   object
#  10  Outlet_Type                1705 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 146.7+ KB

# %%
num = train.select_dtypes('number')
num
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0          12.500         0.006760   42.8112                       1987
# 1          12.600         0.048741   60.4194                       1987
# 2          12.800         0.075997   97.1410                       1987
# 3           6.635         0.046351   37.4506                       2007
# 4          13.500         0.125170  261.4910                       1987
# ...           ...              ...       ...                        ...
# 6813       17.750         0.097863  239.3196                       1999
# 6814       13.000         0.035252   48.0034                       2009
# 6815        4.785         0.092576  121.0098                       2004
# 6816        6.980         0.041189   82.8934                       2002
# 6817          NaN         0.015360  163.7526                       1985
#
#       Item_Outlet_Sales
# 0              639.1680
# 1              990.7104
# 2             2799.6890
# 3             1176.4686
# 4             3418.8830
# ...                 ...
# 6813          3615.2940
# 6814           923.4646
# 6815          2530.7058
# 6816           818.9340
# 6817          1973.4312
#
# [6818 rows x 5 columns]

# %%
num.corr()['Item_Outlet_Sales'].sort_values(ascending=False)
# Out:
# Item_Outlet_Sales            1.000000
# Item_MRP                     0.566721
# Item_Weight                  0.021243
# Outlet_Establishment_Year   -0.051833
# Item_Visibility             -0.124522
# Name: Item_Outlet_Sales, dtype: float64

# %%
train.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1162
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1940
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# Item_Identifier                0
# Item_Weight                  301
# Item_Fat_Content               0
# Item_Visibility                0
# Item_Type                      0
# Item_MRP                       0
# Outlet_Identifier              0
# Outlet_Establishment_Year      0
# Outlet_Size                  470
# Outlet_Location_Type           0
# Outlet_Type                    0
# dtype: int64

# %%
# 오염도 검증 LIB 보고서 사용 - (선택)
# !pip install ydata-profiling
from ydata_profiling import ProfileReport
ProfileReport(train, title="Supermarket Report").to_file("report.html")
# Out:
# Requirement already satisfied: ydata-profiling in /opt/conda/lib/python3.11/site-packages (4.18.4)
# Requirement already satisfied: scipy<1.17,>=1.8 in /opt/conda/lib/python3.11/site-packages (from ydata-profiling) (1.16.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.5 in /opt/conda/lib/python3.11/site-packages (from ydata-profiling) (2.3.3)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in /opt/conda/lib/python3.11/site-packages (from ydata-profiling) (3.10.0)
# Requirement already satisfied: pydantic<3,>=2 in /opt/conda/lib/python3.11/site-packages (from ydata-profiling) (2.13.4)
# Requirement already satisfied: PyYAML<6.1,>=6.0.3 in /opt/conda/lib/python3.11/site-packages (from ydata-profiling) (6.0.3)
# Requirement already satisfied: jinja2<3.2,>=3.1.6 in /opt/conda/lib/python3.11/site-packages (from ydata-profiling) (3.1.6)
# Requirement already satisfied: visions<0.8.2,>=0.7.5 in /opt/conda/lib/python3.11/site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (0.8.1)
# Requirement already satisfied: numpy<2.4,>=1.22 in /opt/conda/lib/python3.11/site-packages (from ydata-profiling) (2.2.6)
# Requirement already satisfied: minify-html>=0.15.0 in /opt/conda/lib/python3.11/site-packages (from ydata-profiling) (0.18.1)
# Requirement already satisfied: filetype>=1.0.0 in /opt/conda/lib/python3.11/site-packages (from ydata-profiling) (1.2.0)
# Requirement already satisfied: phik<0.13,>=0.12.5 in /opt/conda/lib/python3.11/site-packages (from ydata-profiling) (0.12.5)
# Requirement already satisfied: requests<3,>=2.32.0 in /opt/conda/lib/python3.11/site-packages (from ydata-profiling) (2.34.2)
# Requirement already satisfied: tqdm<5,>=4.66.3 in /opt/conda/lib/python3.11/site-packages (from ydata-profiling) (4.69.0)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /opt/conda/lib/python3.11/site-packages (from ydata-profiling) (0.13.0)
# Requirement already satisfied: multimethod<2,>=1.4 in /opt/conda/lib/python3.11/site-packages (from ydata-profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /opt/conda/lib/python3.11/site-packages (from ydata-profiling) (0.14.6)
# Requirement already satisfied: typeguard<5,>=4 in /opt/conda/lib/python3.11/site-packages (from ydata-profiling) (4.5.2)
# Requirement already satisfied: imagehash==4.3.2 in /opt/conda/lib/python3.11/site-packages (from ydata-profiling) (4.3.2)
# Requirement already satisfied: wordcloud>=1.9.4 in /opt/conda/lib/python3.11/site-packages (from ydata-profiling) (1.9.6)
# Requirement already satisfied: dacite<2,>=1.9 in /opt/conda/lib/python3.11/site-packages (from ydata-profiling) (1.9.2)
# Requirement already satisfied: numba<0.63,>=0.60 in /opt/conda/lib/python3.11/site-packages (from ydata-profiling) (0.62.1)
# Requirement already satisfied: PyWavelets in /opt/conda/lib/python3.11/site-packages (from imagehash==4.3.2->ydata-profiling) (1.4.1)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.11/site-packages (from imagehash==4.3.2->ydata-profiling) (10.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2<3.2,>=3.1.6->ydata-profiling) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.11/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.8.2)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in /opt/conda/lib/python3.11/site-packages (from numba<0.63,>=0.60->ydata-profiling) (0.45.1)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2023.3)
# Requirement already satisfied: joblib>=0.14.1 in /opt/conda/lib/python3.11/site-packages (from phik<0.13,>=0.12.5->ydata-profiling) (1.3.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.11/site-packages (from pydantic<3,>=2->ydata-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /opt/conda/lib/python3.11/site-packages (from pydantic<3,>=2->ydata-profiling) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /opt/conda/lib/python3.11/site-packages (from pydantic<3,>=2->ydata-profiling) (4.16.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/conda/lib/python3.11/site-packages (from pydantic<3,>=2->ydata-profiling) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.4)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.32.0->ydata-profiling) (2.0.7)
# Requirement already satisfied: certifi>=2023.5.7 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.32.0->ydata-profiling) (2023.7.22)
# Requirement already satisfied: patsy>=0.5.6 in /opt/conda/lib/python3.11/site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (1.0.2)
# Requirement already satisfied: attrs>=19.3.0 in /opt/conda/lib/python3.11/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (23.1.0)
# Requirement already satisfied: networkx>=2.4 in /opt/conda/lib/python3.11/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.2)
# Requirement already satisfied: puremagic in /opt/conda/lib/python3.11/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (1.30)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling) (1.16.0)
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 12/12 [00:00<00:00, 15993.53it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
#-------------------------------------------------
# 04 데이터전처리
#-------------------------------------------------

# %%
# cat_cols = [c for c in train.columns if train[c].dtype == 'object']
# print('범주형:', cat_cols)

null_series = train.isnull().sum()

null_object_series = null_series[(null_series>0) & (train.dtypes=='object')].index
null_object_series
# Out:
# Index(['Outlet_Size'], dtype='object')

# %%
# cat_cols_float = [c for c in train.columns if train[c].dtype == 'float64']
# print('수치형:', cat_cols_float)

null_float64_series = null_series[(null_series>0) & (train.dtypes=='float64')].index
null_float64_series
# Out:
# Index(['Item_Weight'], dtype='object')

# %%
num_cols = null_float64_series  # 수치형 데이터
cat_cols = null_object_series # 범주형 데이터

# 결측치 채우기 - 이 데이터는 결측이 0이라 실제로 채워지는 값이 없다.
# (결측이 있는 데이터라면 아래처럼 train 기준값으로 train/test를 함께 채운다)

for c in num_cols:
    m = train[c].median()            # train 기준 중앙값
    train[c] = train[c].fillna(m)
    test[c] = test[c].fillna(m)
    
for c in cat_cols:
    m = train[c].mode()[0]           # train 기준 최빈값
    train[c] = train[c].fillna(m)
    test[c] = test[c].fillna(m)
    
print('남은 결측치:', train.isnull().sum().sum(), test.isnull().sum().sum())
# Out:
# 남은 결측치: 0 0

# %%
# train.info()
# test.info()
train.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
#y값 분리
y = train['Item_Outlet_Sales']
y
# Out:
# 0        639.1680
# 1        990.7104
# 2       2799.6890
# 3       1176.4686
# 4       3418.8830
#           ...
# 6813    3615.2940
# 6814     923.4646
# 6815    2530.7058
# 6816     818.9340
# 6817    1973.4312
# Name: Item_Outlet_Sales, Length: 6818, dtype: float64

# %%
train = train.drop(columns=['Item_Outlet_Sales'])
train.shape
# Out:
# (6818, 11)

# %%
#-------------------------------------------------
# 05 검증데이터 분할 및 학습
#-------------------------------------------------

# %%
# 단순 선형 회귀

# %%
from sklearn.linear_model import LinearRegression
X1 = train[['Item_MRP']]  # 특성 1개(2차원 형태로)
lr1 = LinearRegression().fit(X1, y)
print('기울기:', round(lr1.coef_[0], 2), '| 절편:', round(lr1.intercept_, 2))
# 실측: 기울기 15.58, 절편 3.47 → 판매액 = 15.58 x MRP + 3.47 (MRP 1 오르면 판매액 15.58 증가)
# Out:
# 기울기: 15.58 | 절편: 3.47

# %%
#검증 데이터 분할
from sklearn.model_selection import train_test_split
X_tr, X_val, y_tr, y_val = train_test_split(X1, y, test_size=0.2, random_state=0)
lr = LinearRegression().fit(X_tr, y_tr)
pred = lr.predict(X_val)

# %%
# 회귀 평가
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
rmse = np.sqrt(mean_squared_error(y_val, pred))
print('RMSE:', round(rmse, 1))                       # 약 1060
print('MAE :', round(mean_absolute_error(y_val, pred), 1))   # 약 800
print('R2  :', round(r2_score(y_val, pred), 4))      # 약 0.57 (0.5669)
# Out:
# RMSE: 1336.2
# MAE : 996.6
# R2  : 0.3123

# %%
# 다중 선형 회귀

# %%
## 전처리(원핫인코딩)

# %%
X = train.drop(columns=['Item_Outlet_Sales', 'Outlet_Identifier'])
X_test = test.drop(columns=['Item_Identifier', 'Outlet_Identifier'])

all_oh = pd.get_dummies(pd.concat([X, X_test], axis=0))
X = all_oh.iloc[:len(train)]
X_test = all_oh.iloc[len(train):]
print('결측:', X.isnull().sum().sum(), '| 컬럼:', X.shape[1])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 X = train.drop(columns=['Item_Outlet_Sales', 'Outlet_Identifier'])
#       2 X_test = test.drop(columns=['Item_Identifier', 'Outlet_Identifier'])
#       4 all_oh = pd.get_dummies(pd.concat([X, X_test], axis=0))
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)
#    5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)
#    5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/generic.py:4810, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4808 for axis, labels in axes.items():
#    4809     if labels is not None:
# -> 4810         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4812 if inplace:
#    4813     self._update_inplace(obj)
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/generic.py:4852, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4850         new_axis = axis.drop(labels, level=level, errors=errors)
#    4851     else:
# -> 4852         new_axis = axis.drop(labels, errors=errors)
#    4853     indexer = axis.get_indexer(new_axis)
#    4855 # Case for non-unique axis
#    4856 else:
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/indexes/base.py:7136, in Index.drop(self, labels, errors)
#    7134 if mask.any():
#    7135     if errors != "ignore":
# -> 7136         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7137     indexer = indexer[~mask]
#    7138 return self.delete(indexer)
#
# KeyError: "['Item_Outlet_Sales'] not found in axis"

# %%
# num = train.select_dtypes('number')
X.corr()['Item_Outlet_Sales'].sort_values(ascending=False)

# %%
# 검증 데이터 분할
from sklearn.model_selection import train_test_split
X_tr, X_val, y_tr, y_val = train_test_split(X, y, test_size=0.2, random_state=0)
lr = LinearRegression().fit(X_tr, y_tr)
pred = lr.predict(X_val)

# %%
#-------------------------------------------------
# 06 테스트 및 검증지표 확인
#-------------------------------------------------

# %%
#-------------------------------------------------
# 07 Model 내보내기, 테스트파일 내보내기
#-------------------------------------------------
