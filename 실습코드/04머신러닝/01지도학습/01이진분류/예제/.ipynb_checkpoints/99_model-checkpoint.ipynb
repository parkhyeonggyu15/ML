# %%
# IMPORT

# %%
import pandas as pd
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
print('train:', train.shape, '| test:', test.shape)
# Out:
# train: (29304, 16) | test: (3257, 15)

# %%
# y값 분리
y = train['income'].map({'<=50K': 0, '>50K': 1})   # 문자 → 0/1
y
# Out:
# 0        1
# 1        0
# 2        0
# 3        1
# 4        0
#         ..
# 29299    0
# 29300    0
# 29301    0
# 29302    0
# 29303    0
# Name: income, Length: 29304, dtype: int64

# %%
train=train.select_dtypes(include="number");
test=test.select_dtypes(include="number");
train=train.drop(columns=['fnlwgt','capital.gain','capital.loss'])
test=test.drop(columns=['fnlwgt','capital.gain','capital.loss'])

# %%
test
# Out:
#          id   age  education.num  hours.per.week
# 0     11574  39.0             13            40.0
# 1     15847  38.0             10            40.0
# 2     17655  44.0              9             NaN
# 3     19790  47.0             13            50.0
# 4     31812  62.0              9            40.0
# ...     ...   ...            ...             ...
# 3252  20589  28.0             10            40.0
# 3253   5668  52.0              9            40.0
# 3254  27652  25.0              9            38.0
# 3255  14735  36.0              9            40.0
# 3256   4426  60.0              6            10.0
#
# [3257 rows x 4 columns]

# %%
# 데이터 전처리

# %%
num_cols = ['age', 'hours.per.week'] # 수치형 데이터

for c in num_cols:
    m = train[c].median()            # train 기준 중앙값
    train[c] = train[c].fillna(m)
    test[c] = test[c].fillna(m)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29304 entries, 0 to 29303
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              29304 non-null  int64
#  1   age             29304 non-null  float64
#  2   education.num   29304 non-null  int64
#  3   hours.per.week  29304 non-null  float64
# dtypes: float64(2), int64(2)
# memory usage: 915.9 KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3257 entries, 0 to 3256
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              3257 non-null   int64
#  1   age             3257 non-null   float64
#  2   education.num   3257 non-null   int64
#  3   hours.per.week  3257 non-null   float64
# dtypes: float64(2), int64(2)
# memory usage: 101.9 KB

# %%
train.shape
# Out:
# (29304, 4)

# %%
train = train.drop(columns=['id'])
test_id = test['id']                                # 제출용 보관
test = test.drop(columns=['id'])

# %%
test.shape
# Out:
# (3257, 3)

# %%
all_df = pd.concat([train, test], axis=0)           # 합쳐서 인코딩
all_oh = pd.get_dummies(all_df)

# %%
all_oh
# Out:
#        age  education.num  hours.per.week
# 0     34.0             10            40.0
# 1     58.0              9            40.0
# 2     48.0             10            38.0
# 3     58.0             10            40.0
# 4     41.0             10            54.0
# ...    ...            ...             ...
# 3252  28.0             10            40.0
# 3253  52.0              9            40.0
# 3254  25.0              9            38.0
# 3255  36.0              9            40.0
# 3256  60.0              6            10.0
#
# [32561 rows x 3 columns]

# %%
X = all_oh.iloc[:len(train)]                        # 다시 train 부분
X_test = all_oh.iloc[len(train):]                   # test 부분
print('인코딩 후 컬럼 수:', X.shape[1])
# Out:
# 인코딩 후 컬럼 수: 3

# %%
# 검증 데이터 분할
from sklearn.model_selection import train_test_split
X_tr, X_val, y_tr, y_val = train_test_split(
    X, y, test_size=0.2, random_state=0, stratify=y)
print(X_tr.shape, X_val.shape)
# Out:
# (23443, 3) (5861, 3)

# %%
#데이터 학습
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=100, random_state=0)
rf.fit(X_tr, y_tr)
# Out:
# RandomForestClassifier(random_state=0)

# %%
#모델 검증 지표
from sklearn.metrics import accuracy_score, roc_auc_score, classification_report
pred = rf.predict(X_val)
print(pred)
proba = rf.predict_proba(X_val)[:, 1]   # 1(>50K)일 확률 열만 (2차원 슬라이싱)
print(proba)
print('정확도 :', round(accuracy_score(y_val, pred), 4))
print('ROC-AUC:', round(roc_auc_score(y_val, proba), 4))
# print(classification_report(y_val, pred))
# Out:
# [0 0 1 ... 0 0 0]
# [0.47625017 0.01133846 0.7475751  ... 0.         0.         0.        ]
# 정확도 : 0.7674
# ROC-AUC: 0.764

# %%
# 03 test 
rf.predict_proba(X_test)
# Out:
# array([[6.07301862e-01, 3.92698138e-01],
#        [8.02517426e-01, 1.97482574e-01],
#        [7.54779615e-01, 2.45220385e-01],
#        ...,
#        [9.99735779e-01, 2.64221073e-04],
#        [8.37847362e-01, 1.62152638e-01],
#        [7.60000000e-01, 2.40000000e-01]], shape=(3257, 2))

# %%
test_proba = rf.predict_proba(X_test)[:, 1]
submit = pd.DataFrame({'id': test_id, 'income': test_proba})
submit.to_csv('submission.csv', index=False)   # index=False 필수
submit.head(15)
# Out:
#        id    income
# 0   11574  0.392698
# 1   15847  0.197483
# 2   17655  0.245220
# 3   19790  0.553859
# 4   31812  0.267218
# 5    7548  0.267218
# 6   13093  0.882500
# 7   18332  0.248713
# 8   28474  0.868907
# 9    4213  0.000000
# 10  23199  0.431625
# 11   1426  0.126607
# 12  14097  0.000000
# 13  32363  0.289786
# 14  25209  0.134000

# %%
# model.pki 파일변환

# %%
import joblib

joblib.dump(rf, "model.pkl")             # 2) 파일로 저장
# Out:
# ['model.pkl']

# %%
import joblib

bundle = {
    "model":rf, 
    "features": list(X_tr.columns),      # 학습에 쓴 컬럼 순서
    "targets":["<=50K",">50K"],          # 클래스 라벨
}
joblib.dump(bundle, "model.pkl")
# Out:
# ['model.pkl']
